# %% [markdown]
# <a href="https://colab.research.google.com/github/macdonrolex/python_class_20230305/blob/main/%E8%AA%B2%E7%A8%8B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #20230305

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #準備資料

# %%
grades = np.random.randint(30, 101, (10, 4))
df = pd.DataFrame(grades)

# %%
df.columns = ['國文','英文','數學','理化']

# %%
df.index = ["郭雅惠","陳欣虹","王孟修","李政勇","陳仲燦",
            "王寧東","楊雅名","藍冰啟","林玉亨","崔承睿"]

# %%
df
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 陳仲燦   39  74  57  91
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 崔承睿   87  92  77  91

# %% [markdown]
# #讀取特定欄位

# %% [markdown]
# ##讀取所有人的國文成績（單一個欄位）

# %%
df["國文"]
# Out:
# 郭雅惠    100
# 陳欣虹     37
# 王孟修     87
# 李政勇     87
# 陳仲燦     39
# 王寧東     45
# 楊雅名     45
# 藍冰啟     84
# 林玉亨     64
# 崔承睿     87
# Name: 國文, dtype: int64

# %%
type(df["國文"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##同時讀取多個欄位（國文英文同時讀取）
# 使用list

# %%
df[["國文", "英文"]]
# Out:
#       國文  英文
# 郭雅惠  100  51
# 陳欣虹   37  31
# 王孟修   87  56
# 李政勇   87  41
# 陳仲燦   39  74
# 王寧東   45  34
# 楊雅名   45  82
# 藍冰啟   84  46
# 林玉亨   64  81
# 崔承睿   87  92

# %%
df[["國文"]]

# %%
#會變成DataFrame
type(df[["國文"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #讀取單一列資料

# %%
#會因為被判定要讀欄位而失敗
df["郭雅惠"]

# %% [markdown]
# ##使用.loc()及.iloc()

# %%
df.loc["郭雅惠"]
# Out:
# 國文    100
# 英文     51
# 數學     41
# 理化     72
# Name: 郭雅惠, dtype: int64

# %%
df.iloc[0]
# Out:
# 國文    100
# 英文     51
# 數學     41
# 理化     72
# Name: 郭雅惠, dtype: int64

# %% [markdown]
# ##一次讀取多列資料

# %%
df.loc["郭雅惠" : "李政勇"]
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73

# %%
df.loc[["郭雅惠", "李政勇"]]
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 李政勇   87  41  37  73

# %% [markdown]
# ##讀取列的特定欄位資料（如某人的國文和英文成績）

# %%
df.loc["郭雅惠" : "李政勇", ["國文", "英文"]]
# Out:
#       國文  英文
# 郭雅惠  100  51
# 陳欣虹   37  31
# 王孟修   87  56
# 李政勇   87  41

# %% [markdown]
# ## 排序成績資料

# %% [markdown]
# ###將國文成績從高分到低分做排序

# %%
df
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 陳仲燦   39  74  57  91
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 崔承睿   87  92  77  91

# %%
df.sort_values('國文',ascending=False)
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 崔承睿   87  92  77  91
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 陳仲燦   39  74  57  91
# 陳欣虹   37  31  86  44

# %% [markdown]
# ###將國文和英文成績從高分到低分做排序
# 國文順位高

# %%
df.sort_values(["國文", "英文"],ascending=False)
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 崔承睿   87  92  77  91
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 楊雅名   45  82  72  66
# 王寧東   45  34  84  91
# 陳仲燦   39  74  57  91
# 陳欣虹   37  31  86  44

# %% [markdown]
# ###將國文低到高，數學高到低
# 國文順位高

# %%
df.sort_values(["國文", "數學"], ascending=[True, False])
# Out:
#       國文  英文  數學  理化
# 陳欣虹   37  31  86  44
# 陳仲燦   39  74  57  91
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 林玉亨   64  81  98  71
# 藍冰啟   84  46  93  73
# 王孟修   87  56  85  48
# 崔承睿   87  92  77  91
# 李政勇   87  41  37  73
# 郭雅惠  100  51  41  72

# %%
#只看國文英文
df.sort_values(['國文','數學'], ascending=[True, False])[['國文','英文']]
# Out:
#       國文  英文
# 陳欣虹   37  31
# 陳仲燦   39  74
# 王寧東   45  34
# 楊雅名   45  82
# 林玉亨   64  81
# 藍冰啟   84  46
# 王孟修   87  56
# 崔承睿   87  92
# 李政勇   87  41
# 郭雅惠  100  51

# %% [markdown]
# ###根據加權平均做排序

# %%
df['加權平均'] = df['國文']*0.1+df['英文']*0.2+df['數學']*0.4+df['理化']*0.3

# %%
df
# Out:
#       國文  英文  數學  理化  加權平均
# 郭雅惠  100  51  41  72  58.2
# 陳欣虹   37  31  86  44  57.5
# 王孟修   87  56  85  48  68.3
# 李政勇   87  41  37  73  53.6
# 陳仲燦   39  74  57  91  68.8
# 王寧東   45  34  84  91  72.2
# 楊雅名   45  82  72  66  69.5
# 藍冰啟   84  46  93  73  76.7
# 林玉亨   64  81  98  71  83.1
# 崔承睿   87  92  77  91  85.2

# %%
df.sort_values("加權平均", ascending = False)
# Out:
#       國文  英文  數學  理化  加權平均
# 崔承睿   87  92  77  91  85.2
# 林玉亨   64  81  98  71  83.1
# 藍冰啟   84  46  93  73  76.7
# 王寧東   45  34  84  91  72.2
# 楊雅名   45  82  72  66  69.5
# 陳仲燦   39  74  57  91  68.8
# 王孟修   87  56  85  48  68.3
# 郭雅惠  100  51  41  72  58.2
# 陳欣虹   37  31  86  44  57.5
# 李政勇   87  41  37  73  53.6

# %% [markdown]
# # Boolean Indexing / Filtering / Subsetting
# 練習找出國文成績不及格的名單

# %%
df["國文"] < 60
# Out:
# 郭雅惠    False
# 陳欣虹     True
# 王孟修    False
# 李政勇    False
# 陳仲燦     True
# 王寧東     True
# 楊雅名     True
# 藍冰啟    False
# 林玉亨    False
# 崔承睿    False
# Name: 國文, dtype: bool

# %%
df[df['國文'] < 60]
# Out:
#      國文  英文  數學  理化
# 陳欣虹  37  31  86  44
# 陳仲燦  39  74  57  91
# 王寧東  45  34  84  91
# 楊雅名  45  82  72  66

# %% [markdown]
# ### 問題解答
#
# columns 能否用 slicing？

# %%
df

# %%
#失敗
df['國文':'數學']

# %%
#失敗
df.columns['國文':'英文']

# %%
df.columns[0:3]
# Out:
# Index(['國文', '英文', '數學'], dtype='object')

# %%
df[df.columns[0:3]]
# Out:
#       國文  英文  數學
# 郭雅惠  100  51  41
# 陳欣虹   37  31  86
# 王孟修   87  56  85
# 李政勇   87  41  37
# 陳仲燦   39  74  57
# 王寧東   45  34  84
# 楊雅名   45  82  72
# 藍冰啟   84  46  93
# 林玉亨   64  81  98
# 崔承睿   87  92  77

# %% [markdown]
# ##練習（上市公司基本資料查詢）
# https://mopsfin.twse.com.tw/opendata/t187ap03_L.csv

# %%
url = "https://mopsfin.twse.com.tw/opendata/t187ap03_L.csv"

# %%
stock_df = pd.read_csv(url)

# %%
stock_df.head(1)
# Out:
#       出表日期  公司代號        公司名稱 公司簡稱 外國企業註冊地國  產業別             住址  營利事業統一編號  董事長  \
# 0  1120304  1101  臺灣水泥股份有限公司   台泥       －     1  台北市中山北路2段113號  11913502  張安平
#
#    總經理  ...      過戶電話            過戶地址      簽證會計師事務所 簽證會計師1  簽證會計師2  英文簡稱  \
# 0  程耀輝  ...  66365566  台北市重慶南路一段83號5樓  勤業眾信聯合會計師事務所    黃惠敏     郭政弘   TCC
#
#                                               英文通訊地址          傳真機號碼  \
# 0  No.113, Sec.2, Zhongshan N. Rd.,Taipei City 10...  (02)2531-6529
#
#                      電子郵件信箱                           網址
# 0  finance@taiwancement.com  http://www.taiwancement.com
#
# [1 rows x 32 columns]

# %%
#查看資訊
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   出表日期      981 non-null    int64
#  1   公司代號      981 non-null    int64
#  2   公司名稱      981 non-null    object
#  3   公司簡稱      981 non-null    object
#  4   外國企業註冊地國  981 non-null    object
#  5   產業別       981 non-null    int64
#  6   住址        981 non-null    object
#  7   營利事業統一編號  981 non-null    int64
#  8   董事長       981 non-null    object
#  9   總經理       978 non-null    object
#  10  發言人       981 non-null    object
#  11  發言人職稱     981 non-null    object
#  12  代理發言人     978 non-null    object
#  13  總機電話      981 non-null    object
#  14  成立日期      981 non-null    int64
#  15  上市日期      981 non-null    int64
#  16  普通股每股面額   981 non-null    object
#  17  實收資本額     981 non-null    int64
#  18  私募股數      981 non-null    int64
#  19  特別股       981 non-null    int64
#  20  編制財務報表類型  981 non-null    int64
#  21  股票過戶機構    981 non-null    object
#  22  過戶電話      980 non-null    object
#  23  過戶地址      981 non-null    object
#  24  簽證會計師事務所  981 non-null    object
#  25  簽證會計師1    981 non-null    object
#  26  簽證會計師2    978 non-null    object
#  27  英文簡稱      981 non-null    object
#  28  英文通訊地址    981 non-null    object
#  29  傳真機號碼     981 non-null    object
#  30  電子郵件信箱    980 non-null    object
#  31  網址        981 non-null    object
# dtypes: int64(10), object(22)
# memory usage: 245.4+ KB

# %%
stock_df[stock_df["公司代號"] == 2330]
# Out:
#         出表日期  公司代號            公司名稱 公司簡稱 外國企業註冊地國  產業別            住址  營利事業統一編號  \
# 274  1120304  2330  台灣積體電路製造股份有限公司  台積電       －    24  新竹科學園區力行六路8號  22099131
#
#      董事長      總經理  ...          過戶電話            過戶地址      簽證會計師事務所 簽證會計師1  \
# 274  劉德音  總裁: 魏哲家  ...  02-6636-5566  台北市重慶南路一段83號5樓  勤業眾信聯合會計師事務所    江美艷
#
#      簽證會計師2  英文簡稱                                             英文通訊地址  \
# 274     林尚志  TSMC  No. 8, Li-Hsin Rd. 6, Hsinchu Science Park,Hsi...
#
#           傳真機號碼           電子郵件信箱                    網址
# 274  03-5797337  invest@tsmc.com  https://www.tsmc.com
#
# [1 rows x 32 columns]

# %%
stock_df[stock_df["公司代號"] == 2330].iloc[0]
# Out:
# 出表日期                                                  1120304
# 公司代號                                                     2330
# 公司名稱                                           台灣積體電路製造股份有限公司
# 公司簡稱                                                      台積電
# 外國企業註冊地國                                                   －
# 產業別                                                        24
# 住址                                               新竹科學園區力行六路8號
# 營利事業統一編號                                             22099131
# 董事長                                                       劉德音
# 總經理                                                   總裁: 魏哲家
# 發言人                                                       黃仁昭
# 發言人職稱                                                副總經理暨財務長
# 代理發言人                                                     高孟華
# 總機電話                                               03-5636688
# 成立日期                                                 19870221
# 上市日期                                                 19940905
# 普通股每股面額                          新台幣                 10.0000元
# 實收資本額                                            259303804580
# 私募股數                                                        0
# 特別股                                                         0
# 編制財務報表類型                                                    1
# 股票過戶機構                                           中國信託商業銀行 代理部
# 過戶電話                                             02-6636-5566
# 過戶地址                                           台北市重慶南路一段83號5樓
# 簽證會計師事務所                                         勤業眾信聯合會計師事務所
# 簽證會計師1                                                    江美艷
# 簽證會計師2                                                    林尚志
# 英文簡稱                                                     TSMC
# 英文通訊地址      No. 8, Li-Hsin Rd. 6, Hsinchu Science Park,Hsi...
# 傳真機號碼                                              03-5797337
# 電子郵件信箱                                        invest@tsmc.com
# 網址                                       https://www.tsmc.com
# Name: 274, dtype: object

# %%
stock_df[stock_df["公司代號"] == 2330].iloc[0]["公司簡稱"]
# Out:
# '台積電'

# %%
def no2name(stock_no):
  return stock_df[stock_df["公司代號"] == stock_no].iloc[0]["公司簡稱"]

# %%
no2name(2317)
# Out:
# '鴻海'

# %%
#如果股票代號不存在，會出現錯誤
#所以我們使用例外處理，返回錯誤訊息
def no2name01(stock_no):
  try:
    return stock_df[stock_df["公司代號"] == stock_no].iloc[0]["公司簡稱"]
  except Exception as e:
    return "股票代號不存在！"

# %%
no2name01(222)
# Out:
# '股票代號不存在！'

# %% [markdown]
# ##關於Boolean Indexing

# %%
df
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 陳仲燦   39  74  57  91
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 崔承睿   87  92  77  91

# %%
bindex = [True]*5+[False]*5

# %%
bindex
# Out:
# [True, True, True, True, True, False, False, False, False, False]

# %%
df[bindex]
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 陳仲燦   39  74  57  91

# %%
import random

# %%
random.shuffle(bindex)

# %%
bindex
# Out:
# [True, False, False, True, False, True, False, True, True, False]

# %%
df[bindex]
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 李政勇   87  41  37  73
# 王寧東   45  34  84  91
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71

# %% [markdown]
# ##print 跟 return 的差別

# %%
def greetings01(name):
  print(f"Hello, {name}")

# %%
def greetings02(name):
  return f"Hello, {name}"

# %%
m = greetings01('Victor')
# Out:
# Hello, Victor

# %%
n = greetings02('V')

# %%
m

# %%
n
# Out:
# 'Hello, V'

# %% [markdown]
# ## 練習2
#
# 分析台積電的股價 (2330.tw)。
#
# * 下載歷史股價
# * 分析歷史股價第一筆到最近一筆資料的資產變化情形
# * 分析2022年自2023年間，從何時切入投資報酬率最大

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 6.4 MB/s eta 0:00:00
# Collecting cryptography>=3.3.2
#   Downloading cryptography-39.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (2022.7.1)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance) (0.0.11)
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 18.2 MB/s eta 0:00:00
# Collecting requests>=2.26
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 8.5 MB/s eta 0:00:00
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 KB 15.7 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: soupsieve, requests, html5lib, frozendict, cryptography, beautifulsoup4, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.2 cryptography-39.0.2 frozendict-2.3.5 html5lib-1.1 requests-2.28.2 soupsieve-2.4 yfinance-0.2.12

# %%
import yfinance as yf

# %%
TSMC = yf.download('2330.tw')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#從以前到現在漲7倍，close是收盤價
TSMC['Close'][-1]/TSMC['Close'][0]
# Out:
# 7.408573827822822

# %%
TSMC.loc["2022" : "2023"]
# Out:
#              Open   High    Low  Close   Adj Close    Volume
# Date
# 2022-01-03  619.0  632.0  618.0  631.0  617.366455  69089158
# 2022-01-04  645.0  656.0  644.0  656.0  641.826294  79434666
# 2022-01-05  669.0  669.0  646.0  650.0  635.955872  69593809
# 2022-01-06  638.0  646.0  636.0  644.0  630.085571  53210211
# 2022-01-07  643.0  646.0  632.0  634.0  620.301636  38249908
# ...           ...    ...    ...    ...         ...       ...
# 2023-02-23  512.0  521.0  510.0  518.0  518.000000  25376835
# 2023-02-24  524.0  525.0  511.0  511.0  511.000000  41692491
# 2023-03-01  504.0  522.0  504.0  522.0  522.000000  39560848
# 2023-03-02  519.0  520.0  515.0  519.0  519.000000  16558784
# 2023-03-03  524.0  525.0  516.0  516.0  516.000000  23253895
#
# [280 rows x 6 columns]

# %%
#區間最低點
TSMC.loc["2022" : "2023"]["Close"].min()
# Out:
# 371.0

# %%
TSMC['Close']== TSMC.loc['2022':'2023']['Close'].min()
# Out:
# Date
# 2000-01-04    False
# 2000-01-05    False
# 2000-01-06    False
# 2000-01-07    False
# 2000-01-10    False
#               ...
# 2023-02-23    False
# 2023-02-24    False
# 2023-03-01    False
# 2023-03-02    False
# 2023-03-03    False
# Name: Close, Length: 5779, dtype: bool

# %%
TSMC[TSMC['Close']== TSMC.loc['2022':'2023']['Close'].min()]
# Out:
#              Open   High    Low  Close   Adj Close    Volume
# Date
# 2022-10-25  380.0  382.5  371.0  371.0  368.876709  76416687

# %%
TSMC['2022-09':'2022-12']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #合併資料

# %%
HONHAI = yf.download("2317.tw")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#()表示空的DataFrame
STOCKS = pd.DataFrame()

# %%
STOCKS['TSMC'] = TSMC['Close']

# %%
STOCKS['HONHAI'] = HONHAI['Close']

# %%
STOCKS
# Out:
#                 TSMC    HONHAI
# Date
# 2000-01-04  0.160113  0.216109
# 2000-01-05  0.163710  0.216109
# 2000-01-06  0.160113  0.216109
# 2000-01-07  0.155615  0.207387
# 2000-01-10  0.161012  0.211782
# ...              ...       ...
# 2023-02-23  1.190805  1.014778
# 2023-02-24  1.174713  0.995074
# 2023-03-01  1.200000  1.004926
# 2023-03-02  1.193103  1.009852
# 2023-03-03  1.186207  1.009852
#
# [5779 rows x 2 columns]

# %%
STOCKS.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# .tail(100)最近100筆資料 .head（
STOCKS.tail(100).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
STOCKS['TSMC'] = TSMC['Close']/TSMC['Close'].tail(100)[0]
STOCKS['HONHAI'] = HONHAI['Close']/HONHAI['Close'].tail(100)[0]

# %%
STOCKS.tail(100).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #關於回測

# %%
pip install backtesting
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting backtesting
#   Downloading Backtesting-0.3.3.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from backtesting) (1.22.4)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in /usr/local/lib/python3.8/dist-packages (from backtesting) (1.3.5)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from backtesting) (2.4.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.8/dist-packages (from bokeh>=1.4.0->backtesting) (3.1.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.8/dist-packages (from bokeh>=1.4.0->backtesting) (4.5.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.8/dist-packages (from bokeh>=1.4.0->backtesting) (6.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.8/dist-packages (from bokeh>=1.4.0->backtesting) (23.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.8/dist-packages (from bokeh>=1.4.0->backtesting) (6.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.8/dist-packages (from bokeh>=1.4.0->backtesting) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas!=0.25.0,>=0.25.0->backtesting) (1.15.0)
# Building wheels for collected packages: backtesting
#   Building wheel for backtesting (setup.py) ... done
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173819 sha256=61ae7dbcb3b3f8464d2c0e8d215c39b25063ebf667d0f9fb0e8de92c4a95f3de
#   Stored in directory: /root/.cache/pip/wheels/cd/5c/f7/aafe95c37f8b07f838fb0a8cb3177de23a38c09cbd10b447b8
# Successfully built backtesting
# Installing collected packages: backtesting
# Successfully installed backtesting-0.3.3

# %%
from backtesting import Backtest, Strategy
from backtesting.lib import crossover

from backtesting.test import SMA

class SmaCross(Strategy):
    def init(self):
        price = self.data.Close
        self.ma1 = self.I(SMA, price, 10)
        self.ma2 = self.I(SMA, price, 20)

    def next(self):
        if crossover(self.ma1, self.ma2):
            self.buy()
        elif crossover(self.ma2, self.ma1):
            self.sell()

# %%
bt = Backtest(TSMC, SmaCross, commission=.002, exclusive_orders=True)
stats = bt.run()
bt.plot()

# %% [markdown]
# #刪除欄、列

# %%
df
# Out:
#       國文  英文  數學  理化  加權平均
# 郭雅惠  100  51  41  72  58.2
# 陳欣虹   37  31  86  44  57.5
# 王孟修   87  56  85  48  68.3
# 李政勇   87  41  37  73  53.6
# 陳仲燦   39  74  57  91  68.8
# 王寧東   45  34  84  91  72.2
# 楊雅名   45  82  72  66  69.5
# 藍冰啟   84  46  93  73  76.7
# 林玉亨   64  81  98  71  83.1
# 崔承睿   87  92  77  91  85.2

# %%
#不是真的刪除值
df1 = df.drop("王孟修")

# %%
df1
# Out:
#       國文  英文  數學  理化  加權平均
# 郭雅惠  100  51  41  72  58.2
# 陳欣虹   37  31  86  44  57.5
# 李政勇   87  41  37  73  53.6
# 陳仲燦   39  74  57  91  68.8
# 王寧東   45  34  84  91  72.2
# 楊雅名   45  82  72  66  69.5
# 藍冰啟   84  46  93  73  76.7
# 林玉亨   64  81  98  71  83.1
# 崔承睿   87  92  77  91  85.2

# %%
#真的刪掉 inplace = True
df1.drop('王寧東',inplace=True)

# %%
df1
# Out:
#       國文  英文  數學  理化  加權平均
# 郭雅惠  100  51  41  72  58.2
# 陳欣虹   37  31  86  44  57.5
# 李政勇   87  41  37  73  53.6
# 陳仲燦   39  74  57  91  68.8
# 王寧東   45  34  84  91  72.2
# 楊雅名   45  82  72  66  69.5
# 藍冰啟   84  46  93  73  76.7
# 林玉亨   64  81  98  71  83.1
# 崔承睿   87  92  77  91  85.2

# %%
df1.drop('加權平均', axis=1, inplace = True)

# %%
df1
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 李政勇   87  41  37  73
# 陳仲燦   39  74  57  91
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 崔承睿   87  92  77  91

# %% [markdown]
# #遺漏值處理

# %% [markdown]
# ##做出遺漏值

# %%
df.drop("加權平均", axis = 1, inplace = True)

# %%
df
# Out:
#       國文  英文  數學  理化
# 郭雅惠  100  51  41  72
# 陳欣虹   37  31  86  44
# 王孟修   87  56  85  48
# 李政勇   87  41  37  73
# 陳仲燦   39  74  57  91
# 王寧東   45  34  84  91
# 楊雅名   45  82  72  66
# 藍冰啟   84  46  93  73
# 林玉亨   64  81  98  71
# 崔承睿   87  92  77  91

# %%
df.iloc[3:5, 1:3]
# Out:
#      英文  數學
# 李政勇  41  37
# 陳仲燦  74  57

# %%
#隨機選四個位置填上np.nan
for i in range(4):
  m = random.randint(0, 9)
  n = random.randint(0, 3)
  df.iloc[m, n] = np.nan

# %%
df
# Out:
#       國文    英文    數學    理化
# 郭雅惠  100  51.0  41.0   NaN
# 陳欣虹   37  31.0  86.0  44.0
# 王孟修   87   NaN   NaN   NaN
# 李政勇   87  41.0  37.0   NaN
# 陳仲燦   39  74.0  57.0  91.0
# 王寧東   45  34.0  84.0  91.0
# 楊雅名   45  82.0  72.0  66.0
# 藍冰啟   84  46.0  93.0  73.0
# 林玉亨   64   NaN  98.0  71.0
# 崔承睿   87  92.0   NaN  91.0

# %% [markdown]
# ##移除遺漏值
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html?highlight=dropna#pandas.DataFrame.dropna

# %%
#只要有遺漏值就drop
df.dropna()
# Out:
#      國文    英文    數學    理化
# 陳欣虹  37  31.0  86.0  44.0
# 陳仲燦  39  74.0  57.0  91.0
# 王寧東  45  34.0  84.0  91.0
# 楊雅名  45  82.0  72.0  66.0
# 藍冰啟  84  46.0  93.0  73.0

# %%
#刪掉缺失英文的人
df.dropna(subset = ["英文"])
# Out:
#       國文    英文    數學    理化
# 郭雅惠  100  51.0  41.0   NaN
# 陳欣虹   37  31.0  86.0  44.0
# 李政勇   87  41.0  37.0   NaN
# 陳仲燦   39  74.0  57.0  91.0
# 王寧東   45  34.0  84.0  91.0
# 楊雅名   45  82.0  72.0  66.0
# 藍冰啟   84  46.0  93.0  73.0
# 崔承睿   87  92.0   NaN  91.0

# %%
#刪掉缺失英文、理化的人
df.dropna(subset = ["英文", "理化"])
# Out:
#      國文    英文    數學    理化
# 陳欣虹  37  31.0  86.0  44.0
# 陳仲燦  39  74.0  57.0  91.0
# 王寧東  45  34.0  84.0  91.0
# 楊雅名  45  82.0  72.0  66.0
# 藍冰啟  84  46.0  93.0  73.0
# 崔承睿  87  92.0   NaN  91.0

# %% [markdown]
# # 問題解答
#
# 關於 00878 定期定額報酬率評估

# %% [markdown]
# ##抓取00878歷史股價

# %%
HDY = yf.download('00878.tw')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
HDY.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2020-07-10  15.00  15.00  15.00  15.00      15.00       0
# 2020-07-13  14.99  14.99  14.99  14.99      14.99       0
# 2020-07-14  14.98  14.98  14.98  14.98      14.98       0
# 2020-07-15  14.96  14.96  14.96  14.96      14.96       0
# 2020-07-16  14.97  14.97  14.97  14.97      14.97       0

# %%
HDY['Close'].tail(100).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#假設每一次買50000元
CASH = 50000

# %%
#假設定期定額的時限是2022年一整年
for i in range(12):
  print(f"2022-{i+1:02}")
# Out:
# 2022-01
# 2022-02
# 2022-03
# 2022-04
# 2022-05
# 2022-06
# 2022-07
# 2022-08
# 2022-09
# 2022-10
# 2022-11
# 2022-12

# %%
#總共花的錢
TOTALCASH = CASH*12

# %%
#總共買的股票數量
TOTALSTOCK = 0
for i in range(12):
  d = f"2022-{i + 1:02}"
  TOTALSTOCK += CASH / HDY[d]["Close"][0]
# Out:
# <ipython-input-101-21bb25bbd7ba>:4: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   TOTALSTOCK += CASH / HDY[d]["Close"][0]

# %%
TOTALSTOCK
# Out:
# 34131.46725166368

# %%
#2022年底結算總價值/花費的金額
TOTALSTOCK*HDY['2022']['Close'][-1]/TOTALCASH
# Out:
# <ipython-input-104-c6ba52e92ab5>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   TOTALSTOCK*HDY['2022']['Close'][-1]/TOTALCASH
# 0.9198430467723766

# %%
HDY['2022']['Close'].plot()
# Out:
# <ipython-input-105-60beca37971f>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   HDY['2022']['Close'].plot()
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ##如果不是定期定額，報酬率是？

# %%
LUMPSUM = TOTALCASH/HDY['2022']['Close'][0]
# Out:
# <ipython-input-106-eebd0891e058>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   LUMPSUM = TOTALCASH/HDY['2022']['Close'][0]

# %%
LUMPSUM*HDY['2022']['Close'][-1]/TOTALCASH
# Out:
# <ipython-input-107-189f16cf25ec>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   LUMPSUM*HDY['2022']['Close'][-1]/TOTALCASH
# 0.846596845724758
